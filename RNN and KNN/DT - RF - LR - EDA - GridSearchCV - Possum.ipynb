# %% [markdown]
# site - 7 locations across Victoria, New South Wales or Queensland
# sex - male / female (y-variable)
# age - Age of the animal
# hdlndth - head length
# skullw - skull width
# totlngth - total length
# tail - tail length
# footlgth - foot length
# earcounch - ear counch length
# eye - distance from medial canthus to lateral canthus of right eye
# chest - chest girth (in cm)
# belly - belly girth (in cm)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv('possum.csv')
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  tail  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0  36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5  36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5  39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0  38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5  36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %%
df.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#              tail    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %%
df.shape
# Out:
# (104, 14)

# %%
df = df.dropna()
df.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean    52.762376    3.673267    3.821782   92.730693   56.960396   87.269307
# std     30.573894    2.366892    1.915182    3.518714    3.102679    4.196802
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.000000    1.000000    2.000000   90.700000   55.000000   84.500000
# 50%     54.000000    4.000000    3.000000   92.900000   56.400000   88.000000
# 75%     79.000000    6.000000    5.000000   94.800000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#              tail    footlgth    earconch         eye       chest       belly
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean    37.049505   68.398020   48.133663   15.050495   27.064356   32.638614
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      101 non-null    int64
#  1   site      101 non-null    int64
#  2   Pop       101 non-null    object
#  3   sex       101 non-null    object
#  4   age       101 non-null    float64
#  5   hdlngth   101 non-null    float64
#  6   skullw    101 non-null    float64
#  7   totlngth  101 non-null    float64
#  8   tail      101 non-null    float64
#  9   footlgth  101 non-null    float64
#  10  earconch  101 non-null    float64
#  11  eye       101 non-null    float64
#  12  chest     101 non-null    float64
#  13  belly     101 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 11.8+ KB

# %%
import seaborn as sns

# %%
sns.scatterplot(x = 'hdlngth', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='hdlngth', ylabel='sex'>

# %%
sns.scatterplot(x = 'skullw', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='skullw', ylabel='sex'>

# %%
sns.scatterplot(x = 'totlngth', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='totlngth', ylabel='sex'>

# %%
sns.scatterplot(x = 'tail', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='tail', ylabel='sex'>

# %%
sns.scatterplot(x = 'footlgth', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='footlgth', ylabel='sex'>

# %%
sns.scatterplot(x = 'earconch', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='earconch', ylabel='sex'>

# %%
sns.scatterplot(x = 'chest', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='chest', ylabel='sex'>

# %%
sns.scatterplot(x = 'belly', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='belly', ylabel='sex'>

# %%
sns.scatterplot(x = 'age', y = 'sex', hue = 'sex' , data = df)
# Out:
# <Axes: xlabel='age', ylabel='sex'>

# %%
sns.pairplot(df, x_vars=['chest', 'belly', 'age', 'hdlngth', 'skullw'], y_vars='sex', hue = 'sex')

# %%
sns.pairplot(df, x_vars=['totlngth', 'tail', 'footlgth','earconch', 'eye'], y_vars='sex', hue = 'sex')

# %%
X = df.drop(['case','site','Pop','sex'], axis=1)
y = df['sex'] # target column

# %%
X.head()
# Out:
#    age  hdlngth  skullw  totlngth  tail  footlgth  earconch   eye  chest  \
# 0  8.0     94.1    60.4      89.0  36.0      74.5      54.5  15.2   28.0
# 1  6.0     92.5    57.6      91.5  36.5      72.5      51.2  16.0   28.5
# 2  6.0     94.0    60.0      95.5  39.0      75.4      51.9  15.5   30.0
# 3  6.0     93.2    57.1      92.0  38.0      76.1      52.2  15.2   28.0
# 4  2.0     91.5    56.3      85.5  36.0      71.0      53.2  15.1   28.5
#
#    belly
# 0   36.0
# 1   33.0
# 2   34.0
# 3   34.0
# 4   33.0

# %%
y.head()
# Out:
# 0    m
# 1    f
# 2    f
# 3    f
# 4    f
# Name: sex, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
### Decision Tree
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
pred = clf.predict(X_test)
pred
# Out:
# array(['m', 'm', 'f', 'f', 'm', 'f', 'f', 'm', 'f', 'f', 'm', 'm', 'f',
#        'm', 'm', 'm', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'f',
#        'f', 'f', 'f', 'm', 'm'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred, y_test)
# Out:
# 0.5483870967741935

# %%
### Random Forest Classifier
clf = RandomForestClassifier(n_estimators=10)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
clf.score(X_train, y_train)
# Out:
# 0.9571428571428572

# %%
pred = clf.predict(X_test)
pred
# Out:
# array(['f', 'm', 'f', 'f', 'm', 'f', 'm', 'm', 'f', 'm', 'm', 'm', 'f',
#        'm', 'f', 'f', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'f', 'f', 'f',
#        'f', 'f', 'f', 'm', 'm'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred, y_test)
# Out:
# 0.5806451612903226

# %%
### Logistic Regression

# %%
clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
clf.score(X_train, y_train)
# Out:
# 0.7285714285714285

# %%
pred = clf.predict(X_test)
pred
# Out:
# array(['m', 'm', 'f', 'f', 'm', 'm', 'f', 'm', 'f', 'f', 'm', 'f', 'f',
#        'm', 'm', 'f', 'm', 'm', 'm', 'f', 'm', 'm', 'm', 'm', 'f', 'm',
#        'f', 'm', 'f', 'm', 'f'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(pred, y_test)
# Out:
# 0.6774193548387096

# %%
# Predict
# age	hdlngth	skullw	totlngth	tail	footlgth	earconch	eye	chest	belly
new_possum = [ [7.0, 100, 70, 90, 38, 70, 58, 14, 25, 32] ]
clf.predict(new_possum)
# Out:
# array(['m'], dtype=object)

# %%
# Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
tuned_parameters = [{'n_estimators':[1, 50], 'criterion':['gini', 'entropy']}]
model = GridSearchCV(RandomForestClassifier(), tuned_parameters)
model = model.fit(X, y)
prediction = model.predict(X)
model.best_params_
# Out:
# {'criterion': 'entropy', 'n_estimators': 50}
